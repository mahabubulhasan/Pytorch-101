# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

def neural_network(input, weights):
    out = 0
    for i in range(len(input)):
        out += (input[i] * weights[i])
    return out

def ele_mul(scalar, vector):
    out = [0, 0, 0]
    for i in range(len(out)):
        out[i] = vector[i] * scalar
    return out

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

win_or_lose_binary = [1, 1, 0, 1]
true = win_or_lose_binary[0]

alpha = 0.01
weights = [0.1, 0.2, -.1]
input = [toes[0], wlrec[0], nfans[0]]

for iter in range(3):
    pred = neural_network(input, weights)

    error = (pred - true) ** 2
    delta = pred - true

    weight_deltas = ele_mul(delta, input)

    print(f"Itration: {iter + 1}")
    print(f"Pred: {pred:.3f}")
    print(f"Error: {error:.3f}")
    print(f"Delta: {delta:.3f}")
    print(f"Weights: {[f'{w:.3f}' for w in weights]}")
    print(f"Weight_deltas: {[f'{wd:.3f}' for wd in weight_deltas]}")
    print("\n")

    for i in range(len(weights)):
        weights[i] -= alpha * weight_deltas[i]
# Out:
# Itration: 1
# Pred: 0.860
# Error: 0.020
# Delta: -0.140
# Weights: ['0.100', '0.200', '-0.100']
# Weight_deltas: ['-1.190', '-0.091', '-0.168']
#
#
# Itration: 2
# Pred: 0.964
# Error: 0.001
# Delta: -0.036
# Weights: ['0.112', '0.201', '-0.098']
# Weight_deltas: ['-0.308', '-0.024', '-0.043']
#
#
# Itration: 3
# Pred: 0.991
# Error: 0.000
# Delta: -0.009
# Weights: ['0.115', '0.201', '-0.098']
# Weight_deltas: ['-0.080', '-0.006', '-0.011']

# %%
import numpy as np

def neural_network(input, weights):
    out = 0
    for i in range(len(input)):
        out += (input[i] * weights[i])
    return out

def ele_mul(scalar, vector):
    out = [0, 0, 0]
    for i in range(len(out)):
        out[i] = vector[i] * scalar
    return out

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

win_or_lose_binary = [1, 1, 0, 1]
true = win_or_lose_binary[0]

alpha = 0.3
weights = [0.1, 0.2, -.1]
input = [toes[0], wlrec[0], nfans[0]]

for iter in range(3):
    pred = neural_network(input, weights)

    error = (pred - true) ** 2
    delta = pred - true

    weight_deltas = ele_mul(delta, input)
    weight_deltas[0] = 0

    print(f"Itration: {iter + 1}")
    print(f"Pred: {pred:.3f}")
    print(f"Error: {error:.3f}")
    print(f"Delta: {delta:.3f}")
    print(f"Weights: {[f'{w:.3f}' for w in weights]}")
    print(f"Weight_deltas: {[f'{wd:.3f}' for wd in weight_deltas]}")
    print("\n")

    for i in range(len(weights)):
        weights[i] -= alpha * weight_deltas[i]
# Out:
# Itration: 1
# Pred: 0.860
# Error: 0.020
# Delta: -0.140
# Weights: ['0.100', '0.200', '-0.100']
# Weight_deltas: ['0.000', '-0.091', '-0.168']
#
#
# Itration: 2
# Pred: 0.938
# Error: 0.004
# Delta: -0.062
# Weights: ['0.100', '0.227', '-0.050']
# Weight_deltas: ['0.000', '-0.040', '-0.074']
#
#
# Itration: 3
# Pred: 0.973
# Error: 0.001
# Delta: -0.027
# Weights: ['0.100', '0.239', '-0.027']
# Weight_deltas: ['0.000', '-0.018', '-0.033']
